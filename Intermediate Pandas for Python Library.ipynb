# %% [markdown]
# # Intermediate Pandas for Python Library

# %% [markdown]
# This is a task-based intermediate level notebook which should take approximately 1 hour to finish.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("Chicago_Crime_Data-v2.csv")
df.head(5)
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE   False     False  ...  14.0
# 1                         OTHER   False     False  ...  27.0
# 2  NURSING HOME/RETIREMENT HOME   False     False  ...   3.0
# 3                     RESIDENCE   False     False  ...   7.0
# 4                         ALLEY   False     False  ...  15.0
#
#    COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE Y_COORDINATE  YEAR  \
# 0                   58.0        6     1155838.0    1873050.0  2004
# 1                   23.0        6     1152206.0    1906127.0  2004
# 2                   38.0        6     1177436.0    1876313.0  2011
# 3                   46.0        6     1194622.0    1850125.0  2010
# 4                   66.0        6     1155240.0    1860661.0  2016
#
#                 UPDATEDON   LATITUDE  LONGITUDE                       LOCATION
# 0  02/10/2018 03:50:01 PM  41.807441 -87.703956    (41.8074405, -87.703955849)
# 1  02/28/2018 03:56:25 PM  41.898280 -87.716406  (41.898279962, -87.716405505)
# 2  02/10/2018 03:50:01 PM  41.815933 -87.624642  (41.815933131, -87.624642127)
# 3  02/10/2018 03:50:01 PM  41.743665 -87.562463  (41.743665322, -87.562462756)
# 4  02/10/2018 03:50:01 PM  41.773455 -87.706480  (41.773455295, -87.706480471)
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Task 1 : Split Data

# %% [markdown]
# Split data set in three: Training Set, Validation Set and Test Set.

# %%
df_new = df.copy()
df1 = df_new.sample(frac=0.25, random_state=1)
df_new = df_new.drop(df1.index)

df2 = df_new.sample(frac=0.25, random_state=1)
df_new = df_new.drop(df2.index)

df3 = df_new.sample(frac=0.25, random_state=1)
df4 = df_new.drop(df3.index)

# %% [markdown]
# ## Task 2 : Handle Missing Values

# %% [markdown]
# ### Detect Missing Values

# %%
print(df1.isnull().sum())
# Out:
# ID                       0
# CASE_NUMBER              0
# DATE                     0
# BLOCK                    0
# IUCR                     0
# PRIMARY_TYPE             0
# DESCRIPTION              0
# LOCATION_DESCRIPTION     0
# ARREST                   0
# DOMESTIC                 0
# BEAT                     0
# DISTRICT                 0
# WARD                     8
# COMMUNITY_AREA_NUMBER    8
# FBICODE                  0
# X_COORDINATE             1
# Y_COORDINATE             1
# YEAR                     0
# UPDATEDON                0
# LATITUDE                 1
# LONGITUDE                1
# LOCATION                 1
# dtype: int64

# %% [markdown]
# ### Mean Imputation of Missing Values

# %%
df1["WARD"].mean()
# Out:
# 23.336

# %%
df1.isnull()
# Out:
#         ID  CASE_NUMBER   DATE  BLOCK   IUCR  PRIMARY_TYPE  DESCRIPTION  \
# 110  False        False  False  False  False         False        False
# 244  False        False  False  False  False         False        False
# 334  False        False  False  False  False         False        False
# 439  False        False  False  False  False         False        False
# 233  False        False  False  False  False         False        False
# ..     ...          ...    ...    ...    ...           ...          ...
# 58   False        False  False  False  False         False        False
# 480  False        False  False  False  False         False        False
# 274  False        False  False  False  False         False        False
# 179  False        False  False  False  False         False        False
# 168  False        False  False  False  False         False        False
#
#      LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...   WARD  \
# 110                 False   False     False  ...  False
# 244                 False   False     False  ...  False
# 334                 False   False     False  ...  False
# 439                 False   False     False  ...  False
# 233                 False   False     False  ...  False
# ..                    ...     ...       ...  ...    ...
# 58                  False   False     False  ...   True
# 480                 False   False     False  ...  False
# 274                 False   False     False  ...  False
# 179                 False   False     False  ...  False
# 168                 False   False     False  ...  False
#
#      COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE  Y_COORDINATE   YEAR  \
# 110                  False    False         False         False  False
# 244                  False    False         False         False  False
# 334                  False    False         False         False  False
# 439                  False    False         False         False  False
# 233                  False    False         False         False  False
# ..                     ...      ...           ...           ...    ...
# 58                    True    False         False         False  False
# 480                  False    False         False         False  False
# 274                  False    False         False         False  False
# 179                  False    False         False         False  False
# 168                  False    False         False         False  False
#
#      UPDATEDON  LATITUDE  LONGITUDE  LOCATION
# 110      False     False      False     False
# 244      False     False      False     False
# 334      False     False      False     False
# 439      False     False      False     False
# 233      False     False      False     False
# ..         ...       ...        ...       ...
# 58       False     False      False     False
# 480      False     False      False     False
# 274      False     False      False     False
# 179      False     False      False     False
# 168      False     False      False     False
#
# [133 rows x 22 columns]

# %%
df1["WARD"].fillna(df1["WARD"].mean(), inplace = True)

# %%
print(df1.isnull().sum())
# Out:
# ID                       0
# CASE_NUMBER              0
# DATE                     0
# BLOCK                    0
# IUCR                     0
# PRIMARY_TYPE             0
# DESCRIPTION              0
# LOCATION_DESCRIPTION     0
# ARREST                   0
# DOMESTIC                 0
# BEAT                     0
# DISTRICT                 0
# WARD                     0
# COMMUNITY_AREA_NUMBER    8
# FBICODE                  0
# X_COORDINATE             1
# Y_COORDINATE             1
# YEAR                     0
# UPDATEDON                0
# LATITUDE                 1
# LONGITUDE                1
# LOCATION                 1
# dtype: int64

# %% [markdown]
# ### Interpolate Missing Values

# %%
df1["LATITUDE"].fillna(df1["LATITUDE"].interpolate(), inplace = True)

# %%
print(df1.isnull().sum())
# Out:
# ID                       0
# CASE_NUMBER              0
# DATE                     0
# BLOCK                    0
# IUCR                     0
# PRIMARY_TYPE             0
# DESCRIPTION              0
# LOCATION_DESCRIPTION     0
# ARREST                   0
# DOMESTIC                 0
# BEAT                     0
# DISTRICT                 0
# WARD                     0
# COMMUNITY_AREA_NUMBER    8
# FBICODE                  0
# X_COORDINATE             1
# Y_COORDINATE             1
# YEAR                     0
# UPDATEDON                0
# LATITUDE                 0
# LONGITUDE                1
# LOCATION                 1
# dtype: int64

# %% [markdown]
# ## Task 3 : Sorting by Columns and Ranges

# %% [markdown]
# ### Sort Values by a Single Column

# %%
df1.sort_values(by = ["YEAR"], ascending = True)
# Out:
#            ID CASE_NUMBER                    DATE                  BLOCK  \
# 172   1363954     G070193  02/03/2001 03:00:00 AM  004XX W WRIGHTWOOD AV
# 58    1340847     G040244  01/19/2001 06:39:03 PM       063XX N NAGLE AV
# 135   1850651     G688026  11/15/2001 04:00:00 PM     069XX S STEWART AV
# 485   1553689     G302291  05/25/2001 04:34:24 PM     026XX W MADISON ST
# 40    1845995     G662598  11/03/2001 02:26:55 PM       0000X N STATE ST
# ..        ...         ...                     ...                    ...
# 460  10831592    JA133264  01/28/2017 02:52:00 PM  009XX N MASSASOIT AVE
# 519     23469    JA359626  07/23/2017 09:25:00 AM        015XX E 82ND ST
# 439  11057640    JA394755  08/15/2017 12:29:00 PM     021XX W CRYSTAL ST
# 34   10952376    JA272438  05/20/2017 08:30:00 PM        028XX W 21ST ST
# 372  11111810    JA462321  10/07/2017 04:00:00 PM      064XX S MORGAN ST
#
#      IUCR        PRIMARY_TYPE                     DESCRIPTION  \
# 172   460             BATTERY                          SIMPLE
# 58    820               THEFT                  $500 AND UNDER
# 135   430             BATTERY   AGGRAVATED: OTHER DANG WEAPON
# 485  1506        PROSTITUTION           SOLICIT ON PUBLIC WAY
# 40    820               THEFT                  $500 AND UNDER
# ..    ...                 ...                             ...
# 460  031A             ROBBERY                  ARMED: HANDGUN
# 519   110            HOMICIDE             FIRST DEGREE MURDER
# 439  1150  DECEPTIVE PRACTICE               CREDIT CARD FRAUD
# 34    820               THEFT                  $500 AND UNDER
# 372   520             ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
#
#     LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...    WARD  \
# 172            RESIDENCE   False     False  ...  23.336
# 58    GROCERY FOOD STORE    True     False  ...  23.336
# 135             SIDEWALK   False     False  ...  23.336
# 485               STREET    True     False  ...  23.336
# 40      DEPARTMENT STORE    True     False  ...  23.336
# ..                   ...     ...       ...  ...     ...
# 460               STREET   False     False  ...  29.000
# 519               STREET   False     False  ...   8.000
# 439            RESIDENCE   False     False  ...  32.000
# 34              SIDEWALK   False     False  ...  12.000
# 372            APARTMENT    True      True  ...  16.000
#
#      COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE Y_COORDINATE  YEAR  \
# 172                    NaN      08B     1172852.0    1918278.0  2001
# 58                     NaN        6     1132586.0    1941599.0  2001
# 135                    NaN      04B     1174777.0    1859152.0  2001
# 485                    NaN       16     1158862.0    1899877.0  2001
# 40                     NaN        6     1176398.0    1900691.0  2001
# ..                     ...      ...           ...          ...   ...
# 460                   25.0        3     1137854.0    1905671.0  2017
# 519                   45.0      01A     1188090.0    1850923.0  2017
# 439                   24.0       11     1161955.0    1908307.0  2017
# 34                    30.0        6     1157493.0    1889929.0  2017
# 372                   68.0      04A     1170753.0    1862070.0  2017
#
#                   UPDATEDON   LATITUDE  LONGITUDE  \
# 172  08/17/2015 03:03:40 PM  41.931190 -87.640214
# 58   08/17/2015 03:03:40 PM  41.995984 -87.787640
# 135  08/17/2015 03:03:40 PM  41.768901 -87.634907
# 485  08/17/2015 03:03:40 PM  41.880995 -87.692130
# 40   08/17/2015 03:03:40 PM  41.882852 -87.627715
# ..                      ...        ...        ...
# 460  02/14/2017 03:49:42 PM  41.897300 -87.769131
# 519  07/30/2017 03:51:44 PM  41.746013 -87.586371
# 439  02/10/2018 03:50:01 PM  41.904064 -87.680537
# 34   02/10/2018 03:50:01 PM  41.853725 -87.697427
# 372  02/10/2018 03:50:01 PM  41.776997 -87.649572
#
#                           LOCATION
# 172   (41.93119046, -87.640214004)
# 58    (41.99598354, -87.787639887)
# 135  (41.768901335, -87.634907215)
# 485  (41.880995464, -87.692129998)
# 40   (41.882851552, -87.627714909)
# ..                             ...
# 460  (41.897299743, -87.769131006)
# 519   (41.746013191, -87.58637073)
# 439  (41.904064096, -87.680537205)
# 34   (41.853725089, -87.697427476)
# 372  (41.776997403, -87.649572168)
#
# [133 rows x 22 columns]

# %% [markdown]
# ### Sort Values by Row Labels

# %%
df1.sort_index(axis = 0, ascending = True)
# Out:
#            ID CASE_NUMBER                    DATE                  BLOCK  \
# 4    10402076    HZ138551  02/02/2016 07:30:00 PM        033XX W 66TH ST
# 5     7732712    HS540106  09/29/2010 07:59:00 AM    006XX W CHICAGO AVE
# 6    10769475    HZ534771  11/30/2016 01:15:00 AM     050XX N KEDZIE AVE
# 11    7947964    HT180228  02/26/2011 04:00:00 PM     012XX S HALSTED ST
# 17    9681782    HX332132  07/04/2014 09:45:00 PM       079XX S STATE ST
# ..        ...         ...                     ...                    ...
# 519     23469    JA359626  07/23/2017 09:25:00 AM        015XX E 82ND ST
# 521   5738893    HN544458  08/22/2007 05:56:10 PM        016XX E 87TH ST
# 522   9094512    HW238778  04/15/2013 06:52:00 PM  038XX N SPAULDING AVE
# 527   9608166    HX258445  05/12/2014 10:50:00 AM       010XX N WELLS ST
# 528  10453948    HZ192829  03/01/2016 12:00:00 AM        028XX E 79TH ST
#
#      IUCR              PRIMARY_TYPE             DESCRIPTION  \
# 4     820                     THEFT          $500 AND UNDER
# 5     810                     THEFT               OVER $500
# 6     810                     THEFT               OVER $500
# 11    820                     THEFT          $500 AND UNDER
# 17    820                     THEFT          $500 AND UNDER
# ..    ...                       ...                     ...
# 519   110                  HOMICIDE     FIRST DEGREE MURDER
# 521  3960              INTIMIDATION            INTIMIDATION
# 522   583                  STALKING           CYBERSTALKING
# 527  1900  OTHER NARCOTIC VIOLATION  INTOXICATING COMPOUNDS
# 528  1055         HUMAN TRAFFICKING   INVOLUNTARY SERVITUDE
#
#                LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 4                             ALLEY   False     False  ...  15.0
# 5    PARKING LOT/GARAGE(NON.RESID.)   False     False  ...  27.0
# 6                            STREET   False     False  ...  33.0
# 11                    BAR OR TAVERN   False     False  ...  25.0
# 17                     CTA PLATFORM   False     False  ...   6.0
# ..                              ...     ...       ...  ...   ...
# 519                          STREET   False     False  ...   8.0
# 521              SMALL RETAIL STORE   False     False  ...   8.0
# 522                       RESIDENCE   False      True  ...  33.0
# 527                        SIDEWALK    True     False  ...  27.0
# 528                       APARTMENT   False     False  ...   7.0
#
#      COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE Y_COORDINATE  YEAR  \
# 4                     66.0        6     1155240.0    1860661.0  2016
# 5                     24.0        6     1171668.0    1905607.0  2010
# 6                     14.0        6     1154133.0    1933314.0  2016
# 11                    28.0        6     1171230.0    1894421.0  2011
# 17                    44.0        6     1177660.0    1852569.0  2014
# ..                     ...      ...           ...          ...   ...
# 519                   45.0      01A     1188090.0    1850923.0  2017
# 521                   45.0       26     1188659.0    1847618.0  2007
# 522                   16.0      08A     1153706.0    1925344.0  2013
# 527                    8.0       18     1174535.0    1907194.0  2014
# 528                   46.0       26     1196679.0    1853139.0  2016
#
#                   UPDATEDON   LATITUDE  LONGITUDE  \
# 4    02/10/2018 03:50:01 PM  41.773455 -87.706480
# 5    02/10/2018 03:50:01 PM  41.896447 -87.644939
# 6    02/10/2018 03:50:01 PM  41.972845 -87.708600
# 11   02/10/2018 03:50:01 PM  41.865761 -87.646876
# 17   02/10/2018 03:50:01 PM  41.750772 -87.624538
# ..                      ...        ...        ...
# 519  07/30/2017 03:51:44 PM  41.746013 -87.586371
# 521  02/28/2018 03:56:25 PM  41.736930 -87.584391
# 522  02/10/2018 03:50:01 PM  41.950983 -87.710383
# 527  02/10/2018 03:50:01 PM  41.900738 -87.634361
# 528  02/10/2018 03:50:01 PM  41.751885 -87.554826
#
#                           LOCATION
# 4    (41.773455295, -87.706480471)
# 5    (41.896446772, -87.644938678)
# 6    (41.972844913, -87.708600079)
# 11   (41.865761261, -87.646875977)
# 17   (41.750772111, -87.624538423)
# ..                             ...
# 519   (41.746013191, -87.58637073)
# 521  (41.736930377, -87.584391221)
# 522   (41.950983256, -87.71038332)
# 527  (41.900737976, -87.634361322)
# 528  (41.751885152, -87.554825997)
#
# [133 rows x 22 columns]

# %% [markdown]
# ## Task 4 : Selecting and Slicing Data

# %% [markdown]
# ### Selecting Columns by Their Names

# %%
df1[["YEAR", "PRIMARY_TYPE"]]
# Out:
#      YEAR        PRIMARY_TYPE
# 110  2011             BATTERY
# 244  2008     CRIMINAL DAMAGE
# 334  2002       OTHER OFFENSE
# 439  2017  DECEPTIVE PRACTICE
# 233  2003     CRIMINAL DAMAGE
# ..    ...                 ...
# 58   2001               THEFT
# 480  2003   CRIMINAL TRESPASS
# 274  2007           NARCOTICS
# 179  2015             BATTERY
# 168  2002             BATTERY
#
# [133 rows x 2 columns]

# %% [markdown]
# ### Select Columns by Index

# %%
df1[df1.columns[1:5]].head()
# Out:
#     CASE_NUMBER                    DATE                   BLOCK  IUCR
# 110    HT651635  12/29/2011 12:50:00 PM    056XX W ROOSEVELT RD   486
# 244    HP689703  11/18/2008 03:15:00 PM   081XX S LAFAYETTE AVE  1310
# 334    HH692211  10/04/2002 12:00:00 PM     007XX S KENNETH AVE  5002
# 439    JA394755  08/15/2017 12:29:00 PM      021XX W CRYSTAL ST  1150
# 233    HJ527694  07/29/2003 09:25:00 PM  042XX N SACRAMENTO AVE  1310

# %% [markdown]
# ### Slicing

# %%
df.iloc[:3]
# Out:
#         ID CASE_NUMBER                    DATE                     BLOCK IUCR  \
# 0  3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE  890
# 1  3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE  820
# 2  8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE  820
#
#   PRIMARY_TYPE     DESCRIPTION          LOCATION_DESCRIPTION  ARREST  \
# 0        THEFT   FROM BUILDING            SMALL RETAIL STORE   False
# 1        THEFT  $500 AND UNDER                         OTHER   False
# 2        THEFT  $500 AND UNDER  NURSING HOME/RETIREMENT HOME   False
#
#    DOMESTIC  ...  WARD  COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE  \
# 0     False  ...  14.0                   58.0        6     1155838.0
# 1     False  ...  27.0                   23.0        6     1152206.0
# 2     False  ...   3.0                   38.0        6     1177436.0
#
#   Y_COORDINATE  YEAR               UPDATEDON   LATITUDE  LONGITUDE  \
# 0    1873050.0  2004  02/10/2018 03:50:01 PM  41.807441 -87.703956
# 1    1906127.0  2004  02/28/2018 03:56:25 PM  41.898280 -87.716406
# 2    1876313.0  2011  02/10/2018 03:50:01 PM  41.815933 -87.624642
#
#                         LOCATION
# 0    (41.8074405, -87.703955849)
# 1  (41.898279962, -87.716405505)
# 2  (41.815933131, -87.624642127)
#
# [3 rows x 22 columns]

# %%
df.loc[:3]
# Out:
#         ID CASE_NUMBER                    DATE                     BLOCK IUCR  \
# 0  3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE  890
# 1  3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE  820
# 2  8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE  820
# 3  7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE  840
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
#
#    ARREST  DOMESTIC  ...  WARD  COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE  \
# 0   False     False  ...  14.0                   58.0        6     1155838.0
# 1   False     False  ...  27.0                   23.0        6     1152206.0
# 2   False     False  ...   3.0                   38.0        6     1177436.0
# 3   False     False  ...   7.0                   46.0        6     1194622.0
#
#   Y_COORDINATE  YEAR               UPDATEDON   LATITUDE  LONGITUDE  \
# 0    1873050.0  2004  02/10/2018 03:50:01 PM  41.807441 -87.703956
# 1    1906127.0  2004  02/28/2018 03:56:25 PM  41.898280 -87.716406
# 2    1876313.0  2011  02/10/2018 03:50:01 PM  41.815933 -87.624642
# 3    1850125.0  2010  02/10/2018 03:50:01 PM  41.743665 -87.562463
#
#                         LOCATION
# 0    (41.8074405, -87.703955849)
# 1  (41.898279962, -87.716405505)
# 2  (41.815933131, -87.624642127)
# 3  (41.743665322, -87.562462756)
#
# [4 rows x 22 columns]

# %% [markdown]
# ## Task 5 : Joining, Concatenation and Advanced Joins

# %% [markdown]
# ### Joining

# %% [markdown]
# Join function operates only on the columns.

# %%
df5 = df1.join(df2, lsuffix = "_left")
df5
# Out:
#       ID_left CASE_NUMBER_left               DATE_left  \
# 110   8418606         HT651635  12/29/2011 12:50:00 PM
# 244   6620347         HP689703  11/18/2008 03:15:00 PM
# 334   2415583         HH692211  10/04/2002 12:00:00 PM
# 439  11057640         JA394755  08/15/2017 12:29:00 PM
# 233   2862972         HJ527694  07/29/2003 09:25:00 PM
# ..        ...              ...                     ...
# 58    1340847          G040244  01/19/2001 06:39:03 PM
# 480   3081572         HJ804627  12/07/2003 10:16:40 PM
# 274   5547866         HN355411  05/21/2007 09:49:42 AM
# 179  10003235         HY192694  03/21/2015 03:41:00 AM
# 168   2584554         HH867007  12/30/2002 08:41:00 AM
#
#                  BLOCK_left IUCR_left   PRIMARY_TYPE_left  \
# 110    056XX W ROOSEVELT RD       486             BATTERY
# 244   081XX S LAFAYETTE AVE      1310     CRIMINAL DAMAGE
# 334     007XX S KENNETH AVE      5002       OTHER OFFENSE
# 439      021XX W CRYSTAL ST      1150  DECEPTIVE PRACTICE
# 233  042XX N SACRAMENTO AVE      1310     CRIMINAL DAMAGE
# ..                      ...       ...                 ...
# 58         063XX N NAGLE AV       820               THEFT
# 480        002XX W ADAMS ST      1330   CRIMINAL TRESPASS
# 274        004XX N PINE AVE      2027           NARCOTICS
# 179      064XX S OAKLEY AVE       486             BATTERY
# 168  040XX W IRVING PARK RD       499             BATTERY
#
#                 DESCRIPTION_left       LOCATION_DESCRIPTION_left  ARREST_left  \
# 110      DOMESTIC BATTERY SIMPLE  PARKING LOT/GARAGE(NON.RESID.)        False
# 244                  TO PROPERTY                       RESIDENCE        False
# 334        OTHER VEHICLE OFFENSE                          STREET         True
# 439            CREDIT CARD FRAUD                       RESIDENCE        False
# 233                  TO PROPERTY                       RESIDENCE        False
# ..                           ...                             ...          ...
# 58                $500 AND UNDER              GROCERY FOOD STORE         True
# 480                      TO LAND                            BANK         True
# 274                  POSS: CRACK                        SIDEWALK         True
# 179      DOMESTIC BATTERY SIMPLE                       APARTMENT        False
# 168  AGGRAVATED DOMESTIC BATTERY                       RESIDENCE         True
#
#      DOMESTIC_left  ...  WARD  COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE  \
# 110           True  ...   NaN                    NaN      NaN           NaN
# 244          False  ...   NaN                    NaN      NaN           NaN
# 334          False  ...   NaN                    NaN      NaN           NaN
# 439          False  ...   NaN                    NaN      NaN           NaN
# 233          False  ...   NaN                    NaN      NaN           NaN
# ..             ...  ...   ...                    ...      ...           ...
# 58           False  ...   NaN                    NaN      NaN           NaN
# 480          False  ...   NaN                    NaN      NaN           NaN
# 274          False  ...   NaN                    NaN      NaN           NaN
# 179          False  ...   NaN                    NaN      NaN           NaN
# 168           True  ...   NaN                    NaN      NaN           NaN
#
#     Y_COORDINATE  YEAR  UPDATEDON  LATITUDE LONGITUDE  LOCATION
# 110          NaN   NaN        NaN       NaN       NaN       NaN
# 244          NaN   NaN        NaN       NaN       NaN       NaN
# 334          NaN   NaN        NaN       NaN       NaN       NaN
# 439          NaN   NaN        NaN       NaN       NaN       NaN
# 233          NaN   NaN        NaN       NaN       NaN       NaN
# ..           ...   ...        ...       ...       ...       ...
# 58           NaN   NaN        NaN       NaN       NaN       NaN
# 480          NaN   NaN        NaN       NaN       NaN       NaN
# 274          NaN   NaN        NaN       NaN       NaN       NaN
# 179          NaN   NaN        NaN       NaN       NaN       NaN
# 168          NaN   NaN        NaN       NaN       NaN       NaN
#
# [133 rows x 44 columns]

# %% [markdown]
# ### Concatenation

# %% [markdown]
# Concat functions operates on either rows or columns.

# %%
df6 = pd.concat([df1, df2], axis = 0)
df6
# Out:
#            ID CASE_NUMBER                    DATE                      BLOCK  \
# 110   8418606    HT651635  12/29/2011 12:50:00 PM       056XX W ROOSEVELT RD
# 244   6620347    HP689703  11/18/2008 03:15:00 PM      081XX S LAFAYETTE AVE
# 334   2415583    HH692211  10/04/2002 12:00:00 PM        007XX S KENNETH AVE
# 439  11057640    JA394755  08/15/2017 12:29:00 PM         021XX W CRYSTAL ST
# 233   2862972    HJ527694  07/29/2003 09:25:00 PM     042XX N SACRAMENTO AVE
# ..        ...         ...                     ...                        ...
# 399   8321464    HT556032  10/23/2011 11:20:00 AM            029XX E 78TH ST
# 366   3661130    HK751265  11/15/2004 12:59:16 AM       084XX S ELIZABETH ST
# 385   1959865    HH149573  01/26/2002 11:57:10 AM              016XX W 79 ST
# 342   5322667    HN182437  02/17/2007 10:15:00 PM  091XX S COTTAGE GROVE AVE
# 219   9801245    HX448587  09/28/2014 11:00:00 PM  113XX S COTTAGE GROVE AVE
#
#      IUCR        PRIMARY_TYPE                    DESCRIPTION  \
# 110   486             BATTERY        DOMESTIC BATTERY SIMPLE
# 244  1310     CRIMINAL DAMAGE                    TO PROPERTY
# 334  5002       OTHER OFFENSE          OTHER VEHICLE OFFENSE
# 439  1150  DECEPTIVE PRACTICE              CREDIT CARD FRAUD
# 233  1310     CRIMINAL DAMAGE                    TO PROPERTY
# ..    ...                 ...                            ...
# 399   610            BURGLARY                 FORCIBLE ENTRY
# 366   530             ASSAULT  AGGRAVATED: OTHER DANG WEAPON
# 385   610            BURGLARY                 FORCIBLE ENTRY
# 342   560             ASSAULT                         SIMPLE
# 219  1320     CRIMINAL DAMAGE                     TO VEHICLE
#
#                LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 110  PARKING LOT/GARAGE(NON.RESID.)   False      True  ...  29.0
# 244                       RESIDENCE   False     False  ...  21.0
# 334                          STREET    True     False  ...  24.0
# 439                       RESIDENCE   False     False  ...  32.0
# 233                       RESIDENCE   False     False  ...  33.0
# ..                              ...     ...       ...  ...   ...
# 399                       RESIDENCE   False     False  ...   7.0
# 366                          STREET   False     False  ...  21.0
# 385              SMALL RETAIL STORE   False     False  ...   NaN
# 342                        SIDEWALK   False      True  ...   8.0
# 219                          STREET   False     False  ...   9.0
#
#      COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE Y_COORDINATE  YEAR  \
# 110                   25.0      08B     1139135.0    1894124.0  2011
# 244                   44.0       14     1177357.0    1850979.0  2008
# 334                   26.0       26     1146814.0    1896113.0  2002
# 439                   24.0       11     1161955.0    1908307.0  2017
# 233                   16.0       14     1155622.0    1928028.0  2003
# ..                     ...      ...           ...          ...   ...
# 399                   43.0        5     1197014.0    1853942.0  2011
# 366                   71.0      04A     1169464.0    1848751.0  2004
# 385                    NaN        5     1166792.0    1852325.0  2002
# 342                   44.0      08A     1183165.0    1844391.0  2007
# 219                   50.0       14     1181588.0    1829877.0  2014
#
#                   UPDATEDON   LATITUDE  LONGITUDE  \
# 110  02/04/2016 06:33:39 AM  41.865590 -87.764707
# 244  02/10/2018 03:50:01 PM  41.746416 -87.625697
# 334  02/28/2018 03:56:25 PM  41.870905 -87.736466
# 439  02/10/2018 03:50:01 PM  41.904064 -87.680537
# 233  02/10/2018 03:50:01 PM  41.958310 -87.703268
# ..                      ...        ...        ...
# 399  02/10/2018 03:50:01 PM  41.754080 -87.553572
# 366  02/10/2018 03:50:01 PM  41.740476 -87.654683
# 385  02/10/2018 03:50:01 PM  41.750341 -87.664371
# 342  02/28/2018 03:56:25 PM  41.728205 -87.604619
# 219  02/10/2018 03:50:01 PM  41.688413 -87.610842
#
#                           LOCATION
# 110  (41.865590065, -87.764706995)
# 244  (41.746415805, -87.625696672)
# 334   (41.87090509, -87.736465901)
# 439  (41.904064096, -87.680537205)
# 233  (41.958309892, -87.703267639)
# ..                             ...
# 399  (41.754080317, -87.553571733)
# 366  (41.740476349, -87.654682797)
# 385  (41.750341323, -87.664370937)
# 342  (41.728204555, -87.604619408)
# 219  (41.688412751, -87.610842301)
#
# [233 rows x 22 columns]

# %% [markdown]
# ### Advanced Joins - Inner Join

# %%
df7 = pd.merge(df1, df2, on = "DESCRIPTION")
df7
# Out:
#          ID_x CASE_NUMBER_x                  DATE_x                BLOCK_x  \
# 0     8418606      HT651635  12/29/2011 12:50:00 PM   056XX W ROOSEVELT RD
# 1     8418606      HT651635  12/29/2011 12:50:00 PM   056XX W ROOSEVELT RD
# 2     8418606      HT651635  12/29/2011 12:50:00 PM   056XX W ROOSEVELT RD
# 3     8418606      HT651635  12/29/2011 12:50:00 PM   056XX W ROOSEVELT RD
# 4    10179921      HY368284  08/04/2015 04:20:00 AM        024XX S TROY ST
# ..        ...           ...                     ...                    ...
# 515  10653179      HZ403432  08/23/2016 01:48:00 AM        008XX E 65TH ST
# 516  10831592      JA133264  01/28/2017 02:52:00 PM  009XX N MASSASOIT AVE
# 517  10831592      JA133264  01/28/2017 02:52:00 PM  009XX N MASSASOIT AVE
# 518  10831592      JA133264  01/28/2017 02:52:00 PM  009XX N MASSASOIT AVE
# 519   8169210      HT404326  07/18/2011 10:30:00 PM      023XX N MASON AVE
#
#     IUCR_x PRIMARY_TYPE_x                DESCRIPTION  \
# 0      486        BATTERY    DOMESTIC BATTERY SIMPLE
# 1      486        BATTERY    DOMESTIC BATTERY SIMPLE
# 2      486        BATTERY    DOMESTIC BATTERY SIMPLE
# 3      486        BATTERY    DOMESTIC BATTERY SIMPLE
# 4      486        BATTERY    DOMESTIC BATTERY SIMPLE
# ..     ...            ...                        ...
# 515   051A        ASSAULT        AGGRAVATED: HANDGUN
# 516   031A        ROBBERY             ARMED: HANDGUN
# 517   031A        ROBBERY             ARMED: HANDGUN
# 518   031A        ROBBERY             ARMED: HANDGUN
# 519   1562    SEX OFFENSE  AGG CRIMINAL SEXUAL ABUSE
#
#              LOCATION_DESCRIPTION_x  ARREST_x  DOMESTIC_x  ...  WARD_y  \
# 0    PARKING LOT/GARAGE(NON.RESID.)     False        True  ...     4.0
# 1    PARKING LOT/GARAGE(NON.RESID.)     False        True  ...    28.0
# 2    PARKING LOT/GARAGE(NON.RESID.)     False        True  ...     4.0
# 3    PARKING LOT/GARAGE(NON.RESID.)     False        True  ...    25.0
# 4                         APARTMENT      True        True  ...     4.0
# ..                              ...       ...         ...  ...     ...
# 515                       APARTMENT      True        True  ...    28.0
# 516                          STREET     False       False  ...    21.0
# 517                          STREET     False       False  ...     2.0
# 518                          STREET     False       False  ...    24.0
# 519         RESIDENCE PORCH/HALLWAY      True       False  ...    45.0
#
#      COMMUNITY_AREA_NUMBER_y  FBICODE_y  X_COORDINATE_y Y_COORDINATE_y  \
# 0                       39.0        08B       1183133.0      1873130.0
# 1                       25.0        08B       1142023.0      1899535.0
# 2                       39.0        08B       1182938.0      1875792.0
# 3                       31.0        08B       1163120.0      1891403.0
# 4                       39.0        08B       1183133.0      1873130.0
# ..                       ...        ...             ...            ...
# 515                     30.0        04B       1158737.0      1888170.0
# 516                     71.0          3       1170122.0      1848931.0
# 517                     28.0          3       1161099.0      1899441.0
# 518                     29.0          3       1152475.0      1894470.0
# 519                     12.0         17       1142286.0      1934118.0
#
#      YEAR_y             UPDATEDON_y  LATITUDE_y LONGITUDE_y  \
# 0      2016  02/10/2018 03:50:01 PM   41.807068  -87.603844
# 1      2002  02/28/2018 03:56:25 PM   41.880386  -87.753971
# 2      2003  02/28/2018 03:56:25 PM   41.814377  -87.604476
# 3      2005  02/28/2018 03:56:25 PM   41.857654  -87.676733
# 4      2016  02/10/2018 03:50:01 PM   41.807068  -87.603844
# ..      ...                     ...         ...         ...
# 515    2007  02/28/2018 03:56:25 PM   41.848873  -87.692910
# 516    2003  02/10/2018 03:50:01 PM   41.740956  -87.652267
# 517    2017  05/04/2018 03:51:04 PM   41.879753  -87.683928
# 518    2017  02/10/2018 03:50:01 PM   41.866287  -87.715726
# 519    2004  02/28/2018 03:56:25 PM   41.975280  -87.752144
#
#                         LOCATION_y
# 0    (41.807067906, -87.603843747)
# 1    (41.880385563, -87.753970777)
# 2    (41.814377178, -87.604476134)
# 3     (41.85765368, -87.676732923)
# 4    (41.807067906, -87.603843747)
# ..                             ...
# 515  (41.848872832, -87.692909673)
# 516   (41.74095603, -87.652266736)
# 517  (41.879752884, -87.683927994)
# 518  (41.866286618, -87.715725607)
# 519  (41.975279956, -87.752144317)
#
# [520 rows x 43 columns]

# %% [markdown]
# ### Full Outer Inclusive Join

# %%
df8 = pd.merge(df1, df2, how = "outer")
df8
# Out:
#            ID CASE_NUMBER                    DATE                      BLOCK  \
# 0     8418606    HT651635  12/29/2011 12:50:00 PM       056XX W ROOSEVELT RD
# 1     6620347    HP689703  11/18/2008 03:15:00 PM      081XX S LAFAYETTE AVE
# 2     2415583    HH692211  10/04/2002 12:00:00 PM        007XX S KENNETH AVE
# 3    11057640    JA394755  08/15/2017 12:29:00 PM         021XX W CRYSTAL ST
# 4     2862972    HJ527694  07/29/2003 09:25:00 PM     042XX N SACRAMENTO AVE
# ..        ...         ...                     ...                        ...
# 228   8321464    HT556032  10/23/2011 11:20:00 AM            029XX E 78TH ST
# 229   3661130    HK751265  11/15/2004 12:59:16 AM       084XX S ELIZABETH ST
# 230   1959865    HH149573  01/26/2002 11:57:10 AM              016XX W 79 ST
# 231   5322667    HN182437  02/17/2007 10:15:00 PM  091XX S COTTAGE GROVE AVE
# 232   9801245    HX448587  09/28/2014 11:00:00 PM  113XX S COTTAGE GROVE AVE
#
#      IUCR        PRIMARY_TYPE                    DESCRIPTION  \
# 0     486             BATTERY        DOMESTIC BATTERY SIMPLE
# 1    1310     CRIMINAL DAMAGE                    TO PROPERTY
# 2    5002       OTHER OFFENSE          OTHER VEHICLE OFFENSE
# 3    1150  DECEPTIVE PRACTICE              CREDIT CARD FRAUD
# 4    1310     CRIMINAL DAMAGE                    TO PROPERTY
# ..    ...                 ...                            ...
# 228   610            BURGLARY                 FORCIBLE ENTRY
# 229   530             ASSAULT  AGGRAVATED: OTHER DANG WEAPON
# 230   610            BURGLARY                 FORCIBLE ENTRY
# 231   560             ASSAULT                         SIMPLE
# 232  1320     CRIMINAL DAMAGE                     TO VEHICLE
#
#                LOCATION_DESCRIPTION ARREST DOMESTIC  ...  WARD  \
# 0    PARKING LOT/GARAGE(NON.RESID.)  False     True  ...  29.0
# 1                         RESIDENCE  False    False  ...  21.0
# 2                            STREET   True    False  ...  24.0
# 3                         RESIDENCE  False    False  ...  32.0
# 4                         RESIDENCE  False    False  ...  33.0
# ..                              ...    ...      ...  ...   ...
# 228                       RESIDENCE  False    False  ...   7.0
# 229                          STREET  False    False  ...  21.0
# 230              SMALL RETAIL STORE  False    False  ...   NaN
# 231                        SIDEWALK  False     True  ...   8.0
# 232                          STREET  False    False  ...   9.0
#
#      COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE Y_COORDINATE  YEAR  \
# 0                     25.0      08B     1139135.0    1894124.0  2011
# 1                     44.0       14     1177357.0    1850979.0  2008
# 2                     26.0       26     1146814.0    1896113.0  2002
# 3                     24.0       11     1161955.0    1908307.0  2017
# 4                     16.0       14     1155622.0    1928028.0  2003
# ..                     ...      ...           ...          ...   ...
# 228                   43.0        5     1197014.0    1853942.0  2011
# 229                   71.0      04A     1169464.0    1848751.0  2004
# 230                    NaN        5     1166792.0    1852325.0  2002
# 231                   44.0      08A     1183165.0    1844391.0  2007
# 232                   50.0       14     1181588.0    1829877.0  2014
#
#                   UPDATEDON   LATITUDE  LONGITUDE  \
# 0    02/04/2016 06:33:39 AM  41.865590 -87.764707
# 1    02/10/2018 03:50:01 PM  41.746416 -87.625697
# 2    02/28/2018 03:56:25 PM  41.870905 -87.736466
# 3    02/10/2018 03:50:01 PM  41.904064 -87.680537
# 4    02/10/2018 03:50:01 PM  41.958310 -87.703268
# ..                      ...        ...        ...
# 228  02/10/2018 03:50:01 PM  41.754080 -87.553572
# 229  02/10/2018 03:50:01 PM  41.740476 -87.654683
# 230  02/10/2018 03:50:01 PM  41.750341 -87.664371
# 231  02/28/2018 03:56:25 PM  41.728205 -87.604619
# 232  02/10/2018 03:50:01 PM  41.688413 -87.610842
#
#                           LOCATION
# 0    (41.865590065, -87.764706995)
# 1    (41.746415805, -87.625696672)
# 2     (41.87090509, -87.736465901)
# 3    (41.904064096, -87.680537205)
# 4    (41.958309892, -87.703267639)
# ..                             ...
# 228  (41.754080317, -87.553571733)
# 229  (41.740476349, -87.654682797)
# 230  (41.750341323, -87.664370937)
# 231  (41.728204555, -87.604619408)
# 232  (41.688412751, -87.610842301)
#
# [233 rows x 22 columns]

# %% [markdown]
# ### Left Inclusive Join

# %%
df9 = pd.merge(df1, df2, how = "left")
df9
# Out:
#            ID CASE_NUMBER                    DATE                   BLOCK  \
# 0     8418606    HT651635  12/29/2011 12:50:00 PM    056XX W ROOSEVELT RD
# 1     6620347    HP689703  11/18/2008 03:15:00 PM   081XX S LAFAYETTE AVE
# 2     2415583    HH692211  10/04/2002 12:00:00 PM     007XX S KENNETH AVE
# 3    11057640    JA394755  08/15/2017 12:29:00 PM      021XX W CRYSTAL ST
# 4     2862972    HJ527694  07/29/2003 09:25:00 PM  042XX N SACRAMENTO AVE
# ..        ...         ...                     ...                     ...
# 128   1340847     G040244  01/19/2001 06:39:03 PM        063XX N NAGLE AV
# 129   3081572    HJ804627  12/07/2003 10:16:40 PM        002XX W ADAMS ST
# 130   5547866    HN355411  05/21/2007 09:49:42 AM        004XX N PINE AVE
# 131  10003235    HY192694  03/21/2015 03:41:00 AM      064XX S OAKLEY AVE
# 132   2584554    HH867007  12/30/2002 08:41:00 AM  040XX W IRVING PARK RD
#
#      IUCR        PRIMARY_TYPE                  DESCRIPTION  \
# 0     486             BATTERY      DOMESTIC BATTERY SIMPLE
# 1    1310     CRIMINAL DAMAGE                  TO PROPERTY
# 2    5002       OTHER OFFENSE        OTHER VEHICLE OFFENSE
# 3    1150  DECEPTIVE PRACTICE            CREDIT CARD FRAUD
# 4    1310     CRIMINAL DAMAGE                  TO PROPERTY
# ..    ...                 ...                          ...
# 128   820               THEFT               $500 AND UNDER
# 129  1330   CRIMINAL TRESPASS                      TO LAND
# 130  2027           NARCOTICS                  POSS: CRACK
# 131   486             BATTERY      DOMESTIC BATTERY SIMPLE
# 132   499             BATTERY  AGGRAVATED DOMESTIC BATTERY
#
#                LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...    WARD  \
# 0    PARKING LOT/GARAGE(NON.RESID.)   False      True  ...  29.000
# 1                         RESIDENCE   False     False  ...  21.000
# 2                            STREET    True     False  ...  24.000
# 3                         RESIDENCE   False     False  ...  32.000
# 4                         RESIDENCE   False     False  ...  33.000
# ..                              ...     ...       ...  ...     ...
# 128              GROCERY FOOD STORE    True     False  ...  23.336
# 129                            BANK    True     False  ...   2.000
# 130                        SIDEWALK    True     False  ...  28.000
# 131                       APARTMENT   False     False  ...  15.000
# 132                       RESIDENCE    True      True  ...  39.000
#
#      COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE Y_COORDINATE  YEAR  \
# 0                     25.0      08B     1139135.0    1894124.0  2011
# 1                     44.0       14     1177357.0    1850979.0  2008
# 2                     26.0       26     1146814.0    1896113.0  2002
# 3                     24.0       11     1161955.0    1908307.0  2017
# 4                     16.0       14     1155622.0    1928028.0  2003
# ..                     ...      ...           ...          ...   ...
# 128                    NaN        6     1132586.0    1941599.0  2001
# 129                   32.0       26     1174618.0    1899411.0  2003
# 130                   25.0       18     1139465.0    1902293.0  2007
# 131                   66.0      08B     1162182.0    1861826.0  2015
# 132                   16.0      04B     1148845.0    1926278.0  2002
#
#                   UPDATEDON   LATITUDE  LONGITUDE  \
# 0    02/04/2016 06:33:39 AM  41.865590 -87.764707
# 1    02/10/2018 03:50:01 PM  41.746416 -87.625697
# 2    02/28/2018 03:56:25 PM  41.870905 -87.736466
# 3    02/10/2018 03:50:01 PM  41.904064 -87.680537
# 4    02/10/2018 03:50:01 PM  41.958310 -87.703268
# ..                      ...        ...        ...
# 128  08/17/2015 03:03:40 PM  41.995984 -87.787640
# 129  02/28/2018 03:56:25 PM  41.879379 -87.634289
# 130  02/28/2018 03:56:25 PM  41.888001 -87.763296
# 131  02/10/2018 03:50:01 PM  41.776511 -87.681000
# 132  02/28/2018 03:56:25 PM  41.953642 -87.728228
#
#                           LOCATION
# 0    (41.865590065, -87.764706995)
# 1    (41.746415805, -87.625696672)
# 2     (41.87090509, -87.736465901)
# 3    (41.904064096, -87.680537205)
# 4    (41.958309892, -87.703267639)
# ..                             ...
# 128   (41.99598354, -87.787639887)
# 129   (41.87937913, -87.634289354)
# 130  (41.888000869, -87.763296356)
# 131  (41.776510546, -87.681000121)
# 132  (41.953641789, -87.728227991)
#
# [133 rows x 22 columns]

# %% [markdown]
# ### Right Inclusive Join

# %%
df10 = pd.merge(df1, df2, how = "right")
df10
# Out:
#           ID CASE_NUMBER                    DATE                      BLOCK  \
# 0   10840565    JA143710  02/06/2017 01:20:00 PM         009XX N KARLOV AVE
# 1    4044375    HL388623  05/30/2005 08:00:00 PM    008XX S SPRINGFIELD AVE
# 2    3864164    HL239939  12/09/2004 10:22:00 AM           004XX N STATE ST
# 3    4110831    HL446401  06/26/2005 11:59:00 PM            042XX W 26TH ST
# 4    4606754    HM200888  02/25/2006 11:00:00 AM        069XX W HIGGINS AVE
# ..       ...         ...                     ...                        ...
# 95   8321464    HT556032  10/23/2011 11:20:00 AM            029XX E 78TH ST
# 96   3661130    HK751265  11/15/2004 12:59:16 AM       084XX S ELIZABETH ST
# 97   1959865    HH149573  01/26/2002 11:57:10 AM              016XX W 79 ST
# 98   5322667    HN182437  02/17/2007 10:15:00 PM  091XX S COTTAGE GROVE AVE
# 99   9801245    HX448587  09/28/2014 11:00:00 PM  113XX S COTTAGE GROVE AVE
#
#     IUCR                      PRIMARY_TYPE  \
# 0   5073  NON-CRIMINAL (SUBJECT SPECIFIED)
# 1    460                           BATTERY
# 2   1206                DECEPTIVE PRACTICE
# 3    325                           ROBBERY
# 4   1310                   CRIMINAL DAMAGE
# ..   ...                               ...
# 95   610                          BURGLARY
# 96   530                           ASSAULT
# 97   610                          BURGLARY
# 98   560                           ASSAULT
# 99  1320                   CRIMINAL DAMAGE
#
#                                DESCRIPTION LOCATION_DESCRIPTION  ARREST  \
# 0   NOTIFICATION OF CIVIL NO CONTACT ORDER            RESIDENCE   False
# 1                                   SIMPLE             SIDEWALK   False
# 2                THEFT BY LESSEE,MOTOR VEH               STREET    True
# 3                      VEHICULAR HIJACKING               STREET   False
# 4                              TO PROPERTY            RESIDENCE   False
# ..                                     ...                  ...     ...
# 95                          FORCIBLE ENTRY            RESIDENCE   False
# 96           AGGRAVATED: OTHER DANG WEAPON               STREET   False
# 97                          FORCIBLE ENTRY   SMALL RETAIL STORE   False
# 98                                  SIMPLE             SIDEWALK   False
# 99                              TO VEHICLE               STREET   False
#
#     DOMESTIC  ...  WARD  COMMUNITY_AREA_NUMBER  FBICODE  X_COORDINATE  \
# 0       True  ...  37.0                   23.0       26     1148881.0
# 1      False  ...  24.0                   26.0      08B     1150520.0
# 2      False  ...  42.0                    8.0       11     1176302.0
# 3      False  ...  22.0                   30.0        3     1148444.0
# 4      False  ...  41.0                   10.0       14     1129154.0
# ..       ...  ...   ...                    ...      ...           ...
# 95     False  ...   7.0                   43.0        5     1197014.0
# 96     False  ...  21.0                   71.0      04A     1169464.0
# 97     False  ...   NaN                    NaN        5     1166792.0
# 98      True  ...   8.0                   44.0      08A     1183165.0
# 99     False  ...   9.0                   50.0       14     1181588.0
#
#    Y_COORDINATE  YEAR               UPDATEDON   LATITUDE  LONGITUDE  \
# 0     1905963.0  2017  02/14/2017 03:49:42 PM  41.897895 -87.728622
# 1     1895862.0  2005  02/10/2018 03:50:01 PM  41.870145 -87.722866
# 2     1903096.0  2004  02/28/2018 03:56:25 PM  41.889453 -87.627995
# 3     1886380.0  2005  02/28/2018 03:56:25 PM  41.844165 -87.730732
# 4     1935641.0  2006  02/28/2018 03:56:25 PM  41.979694 -87.800401
# ..          ...   ...                     ...        ...        ...
# 95    1853942.0  2011  02/10/2018 03:50:01 PM  41.754080 -87.553572
# 96    1848751.0  2004  02/10/2018 03:50:01 PM  41.740476 -87.654683
# 97    1852325.0  2002  02/10/2018 03:50:01 PM  41.750341 -87.664371
# 98    1844391.0  2007  02/28/2018 03:56:25 PM  41.728205 -87.604619
# 99    1829877.0  2014  02/10/2018 03:50:01 PM  41.688413 -87.610842
#
#                          LOCATION
# 0    (41.89789489, -87.728622316)
# 1     (41.870144798, -87.7228663)
# 2   (41.889453169, -87.627994833)
# 3   (41.844165269, -87.730732326)
# 4   (41.979693542, -87.800401259)
# ..                            ...
# 95  (41.754080317, -87.553571733)
# 96  (41.740476349, -87.654682797)
# 97  (41.750341323, -87.664370937)
# 98  (41.728204555, -87.604619408)
# 99  (41.688412751, -87.610842301)
#
# [100 rows x 22 columns]

# %% [markdown]
# ## Task 6 : Grouping, Calculation of Aggregate and Binning

# %% [markdown]
# ### Group by Multiple Columns

# %%
df1.groupby(["YEAR", "PRIMARY_TYPE"]).groups
# Out:
# {(2001, 'BATTERY'): Int64Index([172, 135], dtype='int64'),
#  (2001, 'CRIMINAL DAMAGE'): Int64Index([237], dtype='int64'),
#  (2001, 'PROSTITUTION'): Int64Index([485], dtype='int64'),
#  (2001, 'THEFT'): Int64Index([90, 40, 58], dtype='int64'),
#  (2002, 'ASSAULT'): Int64Index([345], dtype='int64'),
#  (2002, 'BATTERY'): Int64Index([107, 165, 168], dtype='int64'),
#  (2002, 'MOTOR VEHICLE THEFT'): Int64Index([423], dtype='int64'),
#  (2002, 'OTHER OFFENSE'): Int64Index([334, 341], dtype='int64'),
#  (2002, 'WEAPONS VIOLATION'): Int64Index([493], dtype='int64'),
#  (2003, 'BATTERY'): Int64Index([173], dtype='int64'),
#  (2003, 'BURGLARY'): Int64Index([392], dtype='int64'),
#  (2003, 'CRIMINAL DAMAGE'): Int64Index([233, 250, 255], dtype='int64'),
#  (2003, 'CRIMINAL TRESPASS'): Int64Index([480], dtype='int64'),
#  (2003, 'NARCOTICS'): Int64Index([283, 258], dtype='int64'),
#  (2003, 'ROBBERY'): Int64Index([461], dtype='int64'),
#  (2003, 'THEFT'): Int64Index([78, 85], dtype='int64'),
#  (2005, 'ASSAULT'): Int64Index([365, 363, 358], dtype='int64'),
#  (2005, 'BATTERY'): Int64Index([133], dtype='int64'),
#  (2005, 'BURGLARY'): Int64Index([400], dtype='int64'),
#  (2005, 'CRIMINAL DAMAGE'): Int64Index([214], dtype='int64'),
#  (2005, 'CRIMINAL TRESPASS'): Int64Index([469], dtype='int64'),
#  (2005, 'INTERFERENCE WITH PUBLIC OFFICER'): Int64Index([511], dtype='int64'),
#  (2005, 'NARCOTICS'): Int64Index([304, 261], dtype='int64'),
#  (2006, 'BATTERY'): Int64Index([128, 189], dtype='int64'),
#  (2006, 'BURGLARY'): Int64Index([376], dtype='int64'),
#  (2006, 'CRIMINAL DAMAGE'): Int64Index([225], dtype='int64'),
#  (2006, 'OFFENSE INVOLVING CHILDREN'): Int64Index([502], dtype='int64'),
#  (2006, 'OTHER OFFENSE'): Int64Index([312], dtype='int64'),
#  (2006, 'PROSTITUTION'): Int64Index([487], dtype='int64'),
#  (2006, 'ROBBERY'): Int64Index([449], dtype='int64'),
#  (2006, 'THEFT'): Int64Index([62], dtype='int64'),
#  (2007, 'CRIMINAL DAMAGE'): Int64Index([232, 221], dtype='int64'),
#  (2007, 'CRIMINAL TRESPASS'): Int64Index([474], dtype='int64'),
#  (2007, 'DECEPTIVE PRACTICE'): Int64Index([429, 433], dtype='int64'),
#  (2007, 'INTIMIDATION'): Int64Index([521], dtype='int64'),
#  (2007,
#   'NARCOTICS'): Int64Index([285, 267, 305, 307, 291, 274], dtype='int64'),
#  (2007, 'OFFENSE INVOLVING CHILDREN'): Int64Index([500], dtype='int64'),
#  (2007, 'OTHER OFFENSE'): Int64Index([323], dtype='int64'),
#  (2008, 'CRIMINAL DAMAGE'): Int64Index([244], dtype='int64'),
#  (2008, 'THEFT'): Int64Index([92], dtype='int64'),
#  (2009, 'ASSAULT'): Int64Index([370], dtype='int64'),
#  (2009, 'BATTERY'): Int64Index([192, 132, 197], dtype='int64'),
#  (2009, 'BURGLARY'): Int64Index([374, 389], dtype='int64'),
#  (2009, 'CRIMINAL DAMAGE'): Int64Index([245], dtype='int64'),
#  (2009, 'DECEPTIVE PRACTICE'): Int64Index([430], dtype='int64'),
#  (2009, 'MOTOR VEHICLE THEFT'): Int64Index([422], dtype='int64'),
#  (2009, 'NARCOTICS'): Int64Index([286, 298], dtype='int64'),
#  (2009, 'THEFT'): Int64Index([42, 66, 29], dtype='int64'),
#  (2010, 'BATTERY'): Int64Index([146, 159], dtype='int64'),
#  (2010, 'THEFT'): Int64Index([31, 5], dtype='int64'),
#  (2011, 'BATTERY'): Int64Index([110, 119], dtype='int64'),
#  (2011, 'BURGLARY'): Int64Index([396], dtype='int64'),
#  (2011, 'CRIMINAL DAMAGE'): Int64Index([201], dtype='int64'),
#  (2011, 'NARCOTICS'): Int64Index([292, 289], dtype='int64'),
#  (2011, 'SEX OFFENSE'): Int64Index([509], dtype='int64'),
#  (2011, 'THEFT'): Int64Index([11], dtype='int64'),
#  (2012, 'ASSAULT'): Int64Index([361, 373], dtype='int64'),
#  (2012, 'MOTOR VEHICLE THEFT'): Int64Index([409], dtype='int64'),
#  (2012, 'PROSTITUTION'): Int64Index([488], dtype='int64'),
#  (2012, 'ROBBERY'): Int64Index([458, 463], dtype='int64'),
#  (2012, 'THEFT'): Int64Index([41, 65], dtype='int64'),
#  (2013, 'ASSAULT'): Int64Index([362], dtype='int64'),
#  (2013, 'BATTERY'): Int64Index([142, 187], dtype='int64'),
#  (2013, 'BURGLARY'): Int64Index([379, 402], dtype='int64'),
#  (2013, 'NARCOTICS'): Int64Index([277, 270, 273], dtype='int64'),
#  (2013, 'OTHER OFFENSE'): Int64Index([339], dtype='int64'),
#  (2013, 'STALKING'): Int64Index([522], dtype='int64'),
#  (2014, 'ARSON'): Int64Index([516], dtype='int64'),
#  (2014, 'ASSAULT'): Int64Index([368], dtype='int64'),
#  (2014, 'BATTERY'): Int64Index([185], dtype='int64'),
#  (2014, 'CRIMINAL DAMAGE'): Int64Index([218, 223], dtype='int64'),
#  (2014, 'DECEPTIVE PRACTICE'): Int64Index([443], dtype='int64'),
#  (2014, 'OTHER NARCOTIC VIOLATION'): Int64Index([527], dtype='int64'),
#  (2014, 'THEFT'): Int64Index([47, 67, 17], dtype='int64'),
#  (2015, 'BATTERY'): Int64Index([117, 179], dtype='int64'),
#  (2015, 'DECEPTIVE PRACTICE'): Int64Index([440, 445], dtype='int64'),
#  (2015, 'OTHER OFFENSE'): Int64Index([329], dtype='int64'),
#  (2016, 'ASSAULT'): Int64Index([360], dtype='int64'),
#  (2016, 'CRIMINAL DAMAGE'): Int64Index([246], dtype='int64'),
#  (2016, 'HUMAN TRAFFICKING'): Int64Index([528], dtype='int64'),
#  (2016, 'OTHER OFFENSE'): Int64Index([314], dtype='int64'),
#  (2016, 'THEFT'): Int64Index([4, 102, 6], dtype='int64'),
#  (2017, 'ASSAULT'): Int64Index([372], dtype='int64'),
#  (2017, 'CRIMINAL DAMAGE'): Int64Index([242], dtype='int64'),
#  (2017, 'DECEPTIVE PRACTICE'): Int64Index([439], dtype='int64'),
#  (2017, 'HOMICIDE'): Int64Index([519], dtype='int64'),
#  (2017, 'ROBBERY'): Int64Index([460], dtype='int64'),
#  (2017, 'THEFT'): Int64Index([34], dtype='int64')}

# %% [markdown]
# ### Calculate the Aggregate of a Group

# %%
df1.groupby(["YEAR","PRIMARY_TYPE"]).agg(np.mean)
# Out:
#                                    ID  ARREST  DOMESTIC         BEAT  \
# YEAR PRIMARY_TYPE
# 2001 BATTERY             1.607302e+06     0.0       0.0  1532.500000
#      CRIMINAL DAMAGE     1.414626e+06     0.0       0.0   811.000000
#      PROSTITUTION        1.553689e+06     1.0       0.0  1125.000000
#      THEFT               1.599733e+06     1.0       0.0   618.666667
# 2002 ASSAULT             2.492280e+06     0.0       0.0  2533.000000
# ...                               ...     ...       ...          ...
# 2017 CRIMINAL DAMAGE     1.118573e+07     1.0       0.0  2511.000000
#      DECEPTIVE PRACTICE  1.105764e+07     0.0       0.0  1424.000000
#      HOMICIDE            2.346900e+04     0.0       0.0   411.000000
#      ROBBERY             1.083159e+07     0.0       0.0  1511.000000
#      THEFT               1.095238e+07     0.0       0.0  1023.000000
#
#                          DISTRICT    WARD  COMMUNITY_AREA_NUMBER  \
# YEAR PRIMARY_TYPE
# 2001 BATTERY                 13.0  23.336                    NaN
#      CRIMINAL DAMAGE          8.0  23.336                    NaN
#      PROSTITUTION            11.0  23.336                    NaN
#      THEFT                    6.0  23.336                    NaN
# 2002 ASSAULT                 25.0  37.000                   25.0
# ...                           ...     ...                    ...
# 2017 CRIMINAL DAMAGE         25.0  36.000                   18.0
#      DECEPTIVE PRACTICE      14.0  32.000                   24.0
#      HOMICIDE                 4.0   8.000                   45.0
#      ROBBERY                 15.0  29.000                   25.0
#      THEFT                   10.0  12.000                   30.0
#
#                          X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE
# YEAR PRIMARY_TYPE
# 2001 BATTERY             1.173814e+06     1888715.0  41.850046 -87.637561
#      CRIMINAL DAMAGE     1.130022e+06     1866716.0  41.790539 -87.798788
#      PROSTITUTION        1.158862e+06     1899877.0  41.880995 -87.692130
#      THEFT               1.161801e+06     1914223.0  41.920277 -87.681002
# 2002 ASSAULT             1.142629e+06     1910170.0  41.909558 -87.751481
# ...                               ...           ...        ...        ...
# 2017 CRIMINAL DAMAGE     1.130206e+06     1920118.0  41.937079 -87.796890
#      DECEPTIVE PRACTICE  1.161955e+06     1908307.0  41.904064 -87.680537
#      HOMICIDE            1.188090e+06     1850923.0  41.746013 -87.586371
#      ROBBERY             1.137854e+06     1905671.0  41.897300 -87.769131
#      THEFT               1.157493e+06     1889929.0  41.853725 -87.697427
#
# [88 rows x 11 columns]

# %% [markdown]
# ### Binning Data

# %%
# gives us (rows, columns)
df.shape
# Out:
# (533, 22)

# %%
pd.qcut(df["YEAR"], q = 5).value_counts()
# Out:
# (2000.999, 2003.0]    115
# (2013.6, 2018.0]      107
# (2003.0, 2006.0]      107
# (2009.0, 2013.6]      104
# (2006.0, 2009.0]      100
# Name: YEAR, dtype: int64

# %%
# The End
